# %%
import nfl_data_py as nfl
import numpy as np

np.float_ = np.float64
pbp_data = nfl.import_pbp_data([2024], include_participation=False)
roster_data = nfl.import_weekly_rosters([2024])
roster_data
# Out:
# 2024 done.
# Downcasting floats.
#        season team position depth_chart_position  jersey_number status  \
# 0        2024  SEA       OL                    T           70.0    DEV
# 1        2024  SEA       OL                    T           70.0    DEV
# 2        2024  SEA       OL                    T           70.0    DEV
# 3        2024  SEA       OL                    T           70.0    DEV
# 4        2024  SEA       OL                    T           70.0    DEV
# ...       ...  ...      ...                  ...            ...    ...
# 29290    2024   NO       DL                   DT           76.0    RES
# 29291    2024   NO       DL                   DT           76.0    RES
# 29292    2024  IND       OL                    T           76.0    DEV
# 29293    2024  IND       OL                    T           76.0    DEV
# 29294    2024  IND       OL                    T            NaN    DEV
#
#            player_name first_name last_name birth_date  ...  \
# 0         Jason Peters      Jason    Peters 1982-01-22  ...
# 1         Jason Peters      Jason    Peters 1982-01-22  ...
# 2         Jason Peters      Jason    Peters 1982-01-22  ...
# 3         Jason Peters      Jason    Peters 1982-01-22  ...
# 4         Jason Peters      Jason    Peters 1982-01-22  ...
# ...                ...        ...       ...        ...  ...
# 29290  Camron Peterson     Camron  Peterson 1999-09-13  ...
# 29291  Camron Peterson     Camron  Peterson 1999-09-13  ...
# 29292      Jack Wilson       Jack    Wilson        NaT  ...
# 29293      Jack Wilson       Jack    Wilson        NaT  ...
# 29294      Jack Wilson       Jack    Wilson        NaT  ...
#
#        status_description_abbr  football_name     esb_id gsis_it_id  \
# 0                          P07          Jason  PET150539      29550
# 1                          P07          Jason  PET150539      29550
# 2                          P07          Jason  PET150539      29550
# 3                          P07          Jason  PET150539      29550
# 4                          P07          Jason  PET150539      29550
# ...                        ...            ...        ...        ...
# 29290                      R01         Camron  PAT382575      58061
# 29291                      R01         Camron  PAT382575      58061
# 29292                      P01           Jack  WIL715047      58027
# 29293                      P01           Jack  WIL715047      58027
# 29294                      P01           Jack  WIL715047      58027
#
#                                    smart_id entry_year rookie_year draft_club  \
# 0      32005045-5415-0539-96c0-31361312950f       2004      2004.0       None
# 1      32005045-5415-0539-96c0-31361312950f       2004      2004.0       None
# 2      32005045-5415-0539-96c0-31361312950f       2004      2004.0       None
# 3      32005045-5415-0539-96c0-31361312950f       2004      2004.0       None
# 4      32005045-5415-0539-96c0-31361312950f       2004      2004.0       None
# ...                                     ...        ...         ...        ...
# 29290  32005041-5438-2575-6a39-c3744d58b516       2024      2024.0       None
# 29291  32005041-5438-2575-6a39-c3744d58b516       2024      2024.0       None
# 29292                                  None       2024      2024.0       None
# 29293                                  None       2024      2024.0       None
# 29294                                  None       2024      2024.0       None
#
#       draft_number     age
# 0              NaN  42.762
# 1              NaN  42.839
# 2              NaN  42.782
# 3              NaN  42.716
# 4              NaN  42.820
# ...            ...     ...
# 29290          NaN  25.161
# 29291          NaN  25.084
# 29292          NaN     NaN
# 29293          NaN     NaN
# 29294          NaN     NaN
#
# [29295 rows x 37 columns]
