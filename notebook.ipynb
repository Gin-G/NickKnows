# %%
import nfl_data_py as nfl
import numpy as np

np.float_ = np.float64
pbp_data = nfl.import_pbp_data([2024], include_participation=False)
roster_data = nfl.import_weekly_rosters([2024])
roster_data
# Out:
# 2024 done.
# Downcasting floats.
#       season team position depth_chart_position  jersey_number status  \
# 0       2024  NYJ       QB                   QB            8.0    ACT
# 1       2024  NYJ       QB                   QB            8.0    ACT
# 2       2024  NYJ       QB                   QB            8.0    ACT
# 3       2024  SEA        P                    P            9.0    RET
# 4       2024  SEA        P                    P            9.0    RET
# ...      ...  ...      ...                  ...            ...    ...
# 8178    2024   NE       DL                   DE           30.0    CUT
# 8179    2024  CAR       LB                   LB           41.0    CUT
# 8180    2024   NO       DL                   DT           76.0    RES
# 8181    2024   NO       DL                   DT           76.0    RES
# 8182    2024   NO       DL                   DT           76.0    RES
#
#               player_name first_name  last_name birth_date  ...  \
# 0           Aaron Rodgers      Aaron    Rodgers 1983-12-02  ...
# 1           Aaron Rodgers      Aaron    Rodgers 1983-12-02  ...
# 2           Aaron Rodgers      Aaron    Rodgers 1983-12-02  ...
# 3                Jon Ryan        Jon       Ryan 1981-11-26  ...
# 4                Jon Ryan        Jon       Ryan 1981-11-26  ...
# ...                   ...        ...        ...        ...  ...
# 8178  Christian McCarroll  Christian  McCarroll        NaT  ...
# 8179        Aaron Beasley      Aaron    Beasley 2000-10-03  ...
# 8180      Camron Peterson     Camron   Peterson 1999-09-13  ...
# 8181      Camron Peterson     Camron   Peterson 1999-09-13  ...
# 8182      Camron Peterson     Camron   Peterson 1999-09-13  ...
#
#       status_description_abbr  football_name     esb_id gsis_it_id  \
# 0                         A01          Aaron  ROD339293      29851
# 1                         A01          Aaron  ROD339293      29851
# 2                         A01          Aaron  ROD339293      29851
# 3                         R02            Jon  RYA229481      30714
# 4                         R02            Jon  RYA229481      30714
# ...                       ...            ...        ...        ...
# 8178                      W03      Christian  MCC175443      58058
# 8179                      W03          Aaron  BEA416040      58060
# 8180                      R01         Camron  PAT382575      58061
# 8181                      R01         Camron  PAT382575      58061
# 8182                      R01         Camron  PAT382575      58061
#
#                                   smart_id entry_year rookie_year draft_club  \
# 0     3200524f-4433-9293-a3cf-ad7758d03003       2005      2005.0         GB
# 1     3200524f-4433-9293-a3cf-ad7758d03003       2005      2005.0         GB
# 2     3200524f-4433-9293-a3cf-ad7758d03003       2005      2005.0         GB
# 3     32005259-4122-9481-61e2-b493c152ed78       2006      2006.0       None
# 4     32005259-4122-9481-61e2-b493c152ed78       2006      2006.0       None
# ...                                    ...        ...         ...        ...
# 8178  32004d43-4317-5443-a1e6-84b5eefecfbe       2024      2024.0       None
# 8179  32004245-4141-6040-6ad9-e8707642b097       2024      2024.0       None
# 8180  32005041-5438-2575-6a39-c3744d58b516       2024      2024.0       None
# 8181  32005041-5438-2575-6a39-c3744d58b516       2024      2024.0       None
# 8182  32005041-5438-2575-6a39-c3744d58b516       2024      2024.0       None
#
#      draft_number     age
# 0            24.0  40.772
# 1            24.0  40.799
# 2            24.0  40.789
# 3             NaN  42.823
# 4             NaN  42.804
# ...           ...     ...
# 8178          NaN     NaN
# 8179          NaN  23.932
# 8180          NaN  25.008
# 8181          NaN  24.988
# 8182          NaN  25.027
#
# [8183 rows x 37 columns]
